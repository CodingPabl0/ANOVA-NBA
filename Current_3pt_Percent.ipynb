# %%
from nba_api.stats.endpoints import leagueleaders

LL = leagueleaders.LeagueLeaders()
list_LL = LL.get_data_frames()
LL_df=list_LL[0]

import pandas as pd

# reference used on how to get code >>> Ken Jee

# %%
LL_df
# Out:
#      PLAYER_ID  RANK                 PLAYER TEAM  GP  MIN  FGM  FGA  FG_PCT  \
# 0       203081     1         Damian Lillard  POR  14  507  119  270   0.441
# 1       203897     2            Zach LaVine  CHI  14  498  130  261   0.498
# 2       201939     3          Stephen Curry  GSW  13  449  118  268   0.440
# 3         2544     4           LeBron James  LAL  15  483  128  267   0.479
# 4       203507     5  Giannis Antetokounmpo  MIL  13  413  129  243   0.531
# ..         ...   ...                    ...  ...  ..  ...  ...  ...     ...
# 462    1628390   449      Terrance Ferguson  PHI   5   18    0    3   0.000
# 463    1629033   449            Theo Pinson  NYK   6   16    0    5   0.000
# 464    1628470   449           Torrey Craig  MIL   2   13    0    1   0.000
# 465    1630234   449      Ty-Shon Alexander  PHX   3    8    0    3   0.000
# 466    1628427   449          Vlatko Cancar  DEN   5   14    0    3   0.000
#
# ...

# %%
LL_df.describe()
# Out:
#           PLAYER_ID        RANK          GP         MIN         FGM  \
# count  4.670000e+02  467.000000  467.000000  467.000000  467.000000
# mean   1.135106e+06  232.556745    9.289079  206.738758   34.922912
# std    6.817695e+05  133.690945    4.076515  148.606663   32.294355
# min    2.544000e+03    1.000000    1.000000    1.000000    0.000000
# 25%    2.035005e+05  116.500000    6.000000   64.500000    7.000000
# 50%    1.628372e+06  233.000000   10.000000  198.000000   27.000000
# 75%    1.629632e+06  348.500000   13.000000  336.500000   53.000000
# max    1.630271e+06  449.000000   15.000000  557.000000  133.000000
#
#               FGA      FG_PCT        FG3M        FG3A     FG3_PCT  ...  \
# count  467.000000  467.000000  467.000000  467.000000  467.000000  ...
# mean    75.860814    0.425522   10.982869   30.089936    0.283206  ...
# std     67.489468    0.151459   12.017857   30.352232    0.178160  ...
# ...

# %%
LL_3pt_shooters =LL_df.loc[(LL_df.FG3_PCT >= 0.32) & (LL_df.FG3A >=30 )]

#turn into a percent

print("average mean for current NBA 3 pt shooters is", LL_3pt_shooters.FG3_PCT.mean())
# Out:
# average mean for current NBA 3 pt shooters is 0.3966322580645161

# %%
LL_3pt_shooters.describe()
# Out:
#           PLAYER_ID        RANK          GP         MIN         FGM  \
# count  1.550000e+02  155.000000  155.000000  155.000000  155.000000
# mean   8.979450e+05  114.380645   12.167742  333.477419   61.193548
# std    7.194010e+05   77.503940    2.079021   98.216058   30.295964
# min    2.544000e+03    1.000000    5.000000  111.000000   15.000000
# 25%    2.027075e+05   48.000000   11.000000  249.000000   38.500000
# 50%    2.039990e+05  103.000000   13.000000  344.000000   53.000000
# 75%    1.628422e+06  174.000000   14.000000  407.000000   81.000000
# max    1.630267e+06  288.000000   15.000000  557.000000  133.000000
#
#               FGA      FG_PCT        FG3M        FG3A     FG3_PCT  ...  \
# count  155.000000  155.000000  155.000000  155.000000  155.000000  ...
# mean   132.864516    0.454929   24.387097   61.703226    0.396632  ...
# std     60.873840    0.055049   10.388172   25.561785    0.054412  ...
# ...

# %%
LL_df.columns
# Out:
# Index(['PLAYER_ID', 'RANK', 'PLAYER', 'TEAM', 'GP', 'MIN', 'FGM', 'FGA',
#        'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB',
#        'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'EFF',
#        'AST_TOV', 'STL_TOV'],
#       dtype='object')
